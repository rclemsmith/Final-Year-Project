# %%
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter, ImageOps
from skimage.feature import greycomatrix
import numpy as np
from matplotlib import pyplot as plt
import cv2 as cv
import math

# %%
img = cv.imread('X-Rays/70KV.jpg')  
      
# Apply gamma correction.
image = np.array(255*(img / 255) ** 1.2, dtype = 'uint8')
low_image = Image.fromarray(image)
plt.imshow(low_image)

# %%
img = cv.imread('X-Rays/92KV.jpg')  
      
# Apply gamma correction.
image = np.array(255*(img / 255) ** 1.2, dtype = 'uint8')
high_image = Image.fromarray(image)
plt.imshow(high_image)

# %% [markdown]
# ### L1

# %%
left = 1000
top = 520 
right = 1250
bottom = 650
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 139.014

# %%
left = 1000
top = 520
right = 1250
bottom = 750
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 111.16810434782609

# %% [markdown]
# ## Crop the region containing soft tissues

# %%
left = 1500
top = 1197
right = 1526
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 58.485207100591715

# %%
left = 1449
top = 1196
right = 1480
bottom = 1212
high_cropped_img = high_image.crop((left,top,right,bottom))
# high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 50.381048387096776

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.038054443824907

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %% [markdown]
# <img src = "formula.jpg" />

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.04425499763511187

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.048427165678843476

# %%
M_b1 = Numerator/Denominator

# %%
M_b1
# Out:
# 0.9138465366443217

# %% [markdown]
# ### L2

# %%
left = 1000
top = 785
right = 1250
bottom = 1000
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 130.5849488372093

# %%
left = 1000
top = 785
right = 1250
bottom = 970
high_cropped_img = high_image.crop((left,top,right,bottom))
# high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 110.74627027027027

# %%
left = 1500
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 57.12692307692308

# %%
left = 1449
top = 1192
right = 1480
bottom = 1209
high_cropped_img = high_image.crop((left,top,right,bottom))
# high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 52.20493358633776

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.022779893127899

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.05755176902411119

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.051466801267548073

# %%
M_b2 = Numerator/Denominator

# %%
M_b2
# Out:
# 1.1182309295837263

# %% [markdown]
# ### L3

# %%
left = 1000
top = 985
right = 1250
bottom = 1200
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 113.40351627906976

# %%
left = 1000
top = 985
right = 1250
bottom = 1150
high_cropped_img = high_image.crop((left,top,right,bottom))
# high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 78.39212121212121

# %%
left = 1500
top = 1197
right = 1520
bottom = 1216
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 71.15526315789474

# %%
left = 1449
top = 1191
right = 1480
bottom = 1215
high_cropped_img = high_image.crop((left,top,right,bottom))
# high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 51.806451612903224

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.080392254216233

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.01858019239223463

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.04000194141096963

# %%
M_b3 = Numerator/Denominator

# %%
M_b3
# Out:
# 0.4644822660317039

# %% [markdown]
# ### L4

# %%
left = 950
top = 1185
right = 1250
bottom = 1300
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 117.41866666666667

# %%
left = 1000
top = 1185
right = 1200
bottom = 1350
high_cropped_img = high_image.crop((left,top,right,bottom))
# high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 80.35884848484848

# %%
left = 1501
top = 1197
right = 1520
bottom = 1216
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 71.4404432132964

# %%
left = 1449
top = 1190
right = 1480
bottom = 1221
high_cropped_img = high_image.crop((left,top,right,bottom))
# high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 51.471383975026015

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0831859871225722

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.014348168548970364

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.039445988562608114

# %%
M_b4 = Numerator/Denominator

# %%
M_b4
# Out:
# 0.3637421464592567

# %% [markdown]
# ### T12

# %%
left = 990
top = 340
right = 1230
bottom = 530
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 146.14925438596492

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %%
left = 1000
top = 350
right = 1220
bottom = 520
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 137.90898395721925

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 57.37651821862348

# %%
left = 1449
top = 1190
right = 1480
bottom = 1221
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 67.5525494276795

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 0.9612451160232789

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.24896403501216735

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.0637122219113675

# %%
M_b5 = Numerator/Denominator

# %%
M_b5
# Out:
# 3.9076338501977017

# %%
M_b1 ##L1
# Out:
# 0.9138465366443217

# %%
M_b2 ##L2
# Out:
# 1.1182309295837263

# %%
M_b3 ##L3
# Out:
# 0.4644822660317039

# %%
M_b4 ##L4
# Out:
# 0.3637421464592567

# %%
M_b5 ##T12
# Out:
# 3.9076338501977017

# %%
M_b = (M_b1 + M_b2 + M_b3 + M_b4 + M_b5)/5
M_b
# Out:
# 1.353587145783342

# %% [markdown]
# ### L1 - L2

# %%
left = 990
top = 540
right = 1280
bottom = 980
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 129.20090909090908

# %%
left = 1000
top = 540
right = 1230
bottom = 990
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 124.13340096618357

# %%
left = 1501
top = 1199
right = 1520
bottom = 1213
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 69.09022556390977

# %%
left = 1449
top = 1190
right = 1480
bottom = 1211
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 68.98617511520737

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0003559699629188

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.03829556785420163

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.055929161977379155

# %%
Mb_l1l2 = Numerator/Denominator

# %%
Mb_l1l2
# Out:
# 0.6847155669825783

# %% [markdown]
# ### L1 - L3

# %%
left = 970
top = 550
right = 1290
bottom = 1175
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 120.702585

# %%
left = 980
top = 560
right = 1270
bottom = 1175
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 114.83403980936362

# %%
left = 1501
top = 1197
right = 1517
bottom = 1214
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 66.65073529411765

# %%
left = 1449
top = 1190
right = 1483
bottom = 1224
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 66.2136678200692

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0015691275993661

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.04239845279133192

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05568774360772613

# %%
Mb_l1l3 = Numerator/Denominator

# %%
Mb_l1l3
# Out:
# 0.7613605803458977

# %% [markdown]
# ### L1 - L4

# %%
left = 960
top = 550
right = 1290
bottom = 1320
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 119.17877607241243

# %%
left = 970
top = 560
right = 1270
bottom = 1330
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 113.27657575757576

# %%
left = 1501
top = 1197
right = 1520
bottom = 1213
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 65.20065789473684

# %%
left = 1450
top = 1191
right = 1482
bottom = 1225
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 65.86397058823529

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 0.9975828578317792

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.062224961680287016

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.056481011291475924

# %%
Mb_l1l4 = Numerator/Denominator

# %%
Mb_l1l4
# Out:
# 1.1016970174129648

# %% [markdown]
# ### L2 - L3

# %%
left = 960
top = 770
right = 1280
bottom = 1180
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 117.30315548780487

# %%
left = 980
top = 775
right = 1260
bottom = 1190
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 112.14730636833046

# %%
left = 1501
top = 1197
right = 1520
bottom = 1213
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 65.20065789473684

# %%
left = 1450
top = 1191
right = 1482
bottom = 1226
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 66.07410714285714

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 0.9968246011442441

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.05993570330958775

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05663190437229543

# %%
Mb_l2l3 = Numerator/Denominator

# %%
Mb_l2l3
# Out:
# 1.0583381218398256

# %% [markdown]
# ### L2 - L4

# %%
left = 940
top = 760
right = 1290
bottom = 1340
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 113.91796551724138

# %%
left = 960
top = 770
right = 1270
bottom = 1340
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 109.7003961516695

# %%
left = 1501
top = 1197
right = 1520
bottom = 1213
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 65.20065789473684

# %%
left = 1450
top = 1191
right = 1481
bottom = 1224
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 66.12903225806451

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 0.9966269964171364

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.05357114775728

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05667122771298985

# %%
Mb_l2l4 = Numerator/Denominator

# %%
Mb_l2l4
# Out:
# 0.9452971096477716

# %% [markdown]
# ### L3 - L4

# %%
left = 940
top = 970
right = 1300
bottom = 1340
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 110.54568318318319

# %%
left = 960
top = 970
right = 1270
bottom = 1330
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 105.55595878136201

# %%
left = 1501
top = 1197
right = 1520
bottom = 1213
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 65.20065789473684

# %%
left = 1450
top = 1191
right = 1483
bottom = 1224
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 65.24334251606979

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 0.9998433624040708

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.046917443054199204

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.0560311708815899

# %%
Mb_l3l4 = Numerator/Denominator

# %%
Mb_l3l4
# Out:
# 0.8373453974993553

# %%
Mb_l1l2
# Out:
# 0.6847155669825783

# %%
Mb_l1l3
# Out:
# 0.7613605803458977

# %%
Mb_l1l4
# Out:
# 1.1016970174129648

# %%
Mb_l2l3
# Out:
# 1.0583381218398256

# %%
Mb_l2l4
# Out:
# 0.9452971096477716

# %%
Mb_l3l4
# Out:
# 0.8373453974993553
