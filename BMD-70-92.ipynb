# %%
from PIL import Image, ImageFilter
from skimage.feature import greycomatrix
import numpy as np
from matplotlib import pyplot as plt
import cv2 as c
import math

# %% [markdown]
# ### Taking Top Region Closer to the Whiter Region - 1.543

# %% [markdown]
# ### For low intensity image

# %% [markdown]
# ### OPEN THE IMAGE

# %%
low_image = Image.open("X-Rays/70_40.bmp")
plt.imshow(low_image)

# %% [markdown]
# ### FIND THE WIDTH AND HEIGHT OF THE IMAGE

# %%
width, height = low_image.size
print(width,height)
# Out:
# 128 106

# %% [markdown]
# ### CROP THE REGION OF INTEREST FROM THE IMAGE

# %%
# left = 47
# top = 88.8
# right = 58
# bottom = 94
# low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
# plt.imshow(low_cropped_img)

left = 59
top = 65
right = 70
bottom = 73
low_cropped_img = low_image.crop((left,top,right,bottom))
low_cropped_img.show()
plt.imshow(low_cropped_img)

# %% [markdown]
# ### UNIQUE VALUES FROM AN ARRAY

# %%
np.unique(low_cropped_img)
# Out:
# array([ 89,  91,  92,  94,  95,  96,  99, 105, 109, 110, 111, 112, 113,
#        114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124], dtype=uint8)

# %% [markdown]
# ### AVERAGE PIXEL INTENSITY

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 112.93181818181819

# %% [markdown]
# ### For High intensity image

# %% [markdown]
# ### OPEN THE IMAGE

# %%
high_image = Image.open("X-Rays/92_80.bmp")
plt.imshow(high_image)

# %% [markdown]
# ### FIND THE WIDTH AND HEIGHT OF THE IMAGE

# %%
width, height = high_image.size
print(width,height)
# Out:
# 128 106

# %% [markdown]
# ### CROP THE REGION OF INTEREST FROM THE IMAGE

# %%
# left = 65
# top = 23
# right = 75
# bottom = 27
# high_cropped_img = high_image.crop((left,top,right,bottom))
# high_cropped_img.show()
# plt.imshow(high_cropped_img)

left = 59
top = 60
right = 71
bottom = 68
high_cropped_img = high_image.crop((left,top,right,bottom))
high_cropped_img.show()
plt.imshow(high_cropped_img)

# %% [markdown]
# ### UNIQUE VALUES FROM AN ARRAY

# %%
np.unique(high_cropped_img)
# Out:
# array([ 83,  84,  85,  87,  91,  92,  93,  94,  95,  96,  97,  98,  99,
#        100, 101, 102, 103, 104, 105, 106, 108, 109, 110, 112, 119, 120,
#        123, 126], dtype=uint8)

# %% [markdown]
# ### AVERAGE PIXEL INTENSITY

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 98.875

# %%
low_image = Image.open("X-Rays/70_40.bmp")
plt.imshow(low_image)

# %% [markdown]
# ### Find K Value for Low Intensity

# %%
left = 59
top = 73
right = 70
bottom = 77
low_cropped_img = low_image.crop((left,top,right,bottom))
low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 74.52272727272727

# %%
high_image = Image.open("X-Rays/92_80.bmp")
plt.imshow(high_image)

# %% [markdown]
# ### Find K Value for High Intensity

# %%
left = 59
top = 68
right = 70
bottom = 72
high_cropped_img = high_image.crop((left,top,right,bottom))
high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 46.5

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.12284351827631

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
low_avg_pixel_intensity
# Out:
# 112.93181818181819

# %%
high_avg_pixel_intensity
# Out:
# 98.875

# %%
math.log(low_avg_pixel_intensity)
# Out:
# 4.726784257684059

# %%
(K * math.log(high_avg_pixel_intensity))
# Out:
# 5.158181911924681

# %%
math.log(high_avg_pixel_intensity)
# Out:
# 4.593856426087818

# %%
print(math.log(low_avg_pixel_intensity))
print(K * math.log(high_avg_pixel_intensity))
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 4.726784257684059
# 5.158181911924681
# -0.43139765424062126

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
K
# Out:
# 0.031554139863014335
# 1.12284351827631

# %%
M_b = Numerator/Denominator

# %%
print(M_b)
# Out:
# -13.671665781841732

# %%
1.543-M_b
# Out:
# 15.214665781841731

# %%
k_some = 0.192/0.163

# %% [markdown]
# k_some = 0.1823/0.165

# %%
k_some
# Out:
# 1.177914110429448

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (k_some * math.log(high_avg_pixel_intensity))
print(Numerator)
# Out:
# -0.6843840478917755

# %%
Denominator = mu_b_low - (k_some * mu_b_high)
print(Denominator)
# Out:
# 0.02059509202453985

# %%
M_b = Numerator/Denominator
M_b
# Out:
# -33.23044379099182

# %%
1.543-M_b
# Out:
# 34.77344379099182

# %%
0.02568454545454546 * 1.003
# Out:
# 0.025761599090909092

# %% [markdown]
# ### Taking Center Region - 1.043

# %% [markdown]
# ### For low intensity image

# %% [markdown]
# ### OPEN THE IMAGE

# %%
low_image = Image.open("X-Rays/70_40.bmp")
plt.imshow(low_image)

# %% [markdown]
# ### FIND THE WIDTH AND HEIGHT OF THE IMAGE

# %%
width, height = low_image.size
print(width,height)
# Out:
# 128 106

# %% [markdown]
# ### CROP THE REGION OF INTEREST FROM THE IMAGE

# %%
left = 58
top = 55
right = 70
bottom = 60
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %% [markdown]
# ### UNIQUE VALUES FROM AN ARRAY

# %%
np.unique(low_cropped_img)
# Out:
# array([104, 106, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 119,
#        120, 121, 124, 126, 127], dtype=uint8)

# %% [markdown]
# ### AVERAGE PIXEL INTENSITY

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 113.7

# %% [markdown]
# ### For High intensity image

# %% [markdown]
# ### OPEN THE IMAGE

# %%
high_image = Image.open("X-Rays/92_80.bmp")
plt.imshow(high_image)

# %% [markdown]
# ### FIND THE WIDTH AND HEIGHT OF THE IMAGE

# %%
width, height = high_image.size
print(width,height)
# Out:
# 128 106

# %% [markdown]
# ### CROP THE REGION OF INTEREST FROM THE IMAGE

# %%
# left = 65
# top = 23
# right = 75
# bottom = 27
# high_cropped_img = high_image.crop((left,top,right,bottom))
# high_cropped_img.show()
# plt.imshow(high_cropped_img)

left = 59
top = 47
right = 71
bottom = 56
high_cropped_img = high_image.crop((left,top,right,bottom))
high_cropped_img.show()
plt.imshow(high_cropped_img)

# %% [markdown]
# ### UNIQUE VALUES FROM AN ARRAY

# %%
np.unique(high_cropped_img)
# Out:
# array([ 66,  67,  68,  72,  74,  85,  88,  89,  90,  91,  92,  93,  94,
#         95,  96,  97,  98,  99, 100, 101, 102, 104, 105, 106, 107, 108,
#        110, 112, 114, 115], dtype=uint8)

# %% [markdown]
# ### AVERAGE PIXEL INTENSITY

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 93.14814814814815

# %%
low_image = Image.open("X-Rays/70_40.bmp")
plt.imshow(low_image)

# %% [markdown]
# ### Find K Value for Low Intensity

# %%
left = 59
top = 73
right = 70
bottom = 77
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 74.52272727272727

# %%
high_image = Image.open("X-Rays/92_80.bmp")
plt.imshow(high_image)

# %% [markdown]
# ### Find K Value for High Intensity

# %%
left = 59
top = 68
right = 70
bottom = 72
high_cropped_img = high_image.crop((left,top,right,bottom))
high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 46.5

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K = 1.0898820538842497
K
# Out:
# 1.0898820538842497

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.189

# %%
low_avg_pixel_intensity
# Out:
# 113.7

# %%
high_avg_pixel_intensity
# Out:
# 93.14814814814815

# %%
math.log(low_avg_pixel_intensity)
# Out:
# 4.73356340075649

# %%
(K * math.log(high_avg_pixel_intensity))
# Out:
# 4.941733635775108

# %%
math.log(high_avg_pixel_intensity)
# Out:
# 4.534191216529511

# %%
print(math.log(low_avg_pixel_intensity))
print(K * math.log(high_avg_pixel_intensity))
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 4.73356340075649
# 4.941733635775108
# -0.20817023501861787

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
K
# Out:
# 0.049012291815876796
# 1.0898820538842497

# %%
M_b = Numerator/Denominator

# %%
print(M_b)
# Out:
# -4.247306691975262

# %%
1.043-M_b
# Out:
# 5.290306691975262

# %%
k_some = 0.192/0.163

# %% [markdown]
# k_some = 0.1823/0.165

# %%
k_some
# Out:
# 1.177914110429448

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (k_some * math.log(high_avg_pixel_intensity))
print(Numerator)
# Out:
# -0.6073244125788841

# %%
Denominator = mu_b_low - (k_some * mu_b_high)
print(Denominator)
# Out:
# 0.032374233128834334

# %%
M_b = Numerator/Denominator

# %%
1.043-M_b
# Out:
# 19.80249957368925

# %%
0.02568454545454546 * 1.003
# Out:
# 0.025761599090909092

# %% [markdown]
# ### Taking Bottom Region Away from Whiter Part - 0.54

# %% [markdown]
# ### For low intensity image

# %% [markdown]
# ### OPEN THE IMAGE

# %%
low_image = Image.open("X-Rays/70_40.bmp")
plt.imshow(low_image)

# %% [markdown]
# ### FIND THE WIDTH AND HEIGHT OF THE IMAGE

# %%
width, height = low_image.size
print(width,height)
# Out:
# 128 106

# %% [markdown]
# ### CROP THE REGION OF INTEREST FROM THE IMAGE

# %%
left = 58
top = 42
right = 70
bottom = 48
low_cropped_img = low_image.crop((left,top,right,bottom))
low_cropped_img.show()
plt.imshow(low_cropped_img)

# %% [markdown]
# ### UNIQUE VALUES FROM AN ARRAY

# %%
np.unique(low_cropped_img)
# Out:
# array([100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 112, 113,
#        115, 116], dtype=uint8)

# %% [markdown]
# ### AVERAGE PIXEL INTENSITY

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 105.77777777777777

# %% [markdown]
# ### For High intensity image

# %% [markdown]
# ### OPEN THE IMAGE

# %%
high_image = Image.open("X-Rays/92_80.bmp")
plt.imshow(high_image)

# %% [markdown]
# ### FIND THE WIDTH AND HEIGHT OF THE IMAGE

# %%
width, height = high_image.size
print(width,height)
# Out:
# 128 106

# %% [markdown]
# ### CROP THE REGION OF INTEREST FROM THE IMAGE

# %%
left = 59
top = 34
right = 71
bottom = 44
high_cropped_img = high_image.crop((left,top,right,bottom))
high_cropped_img.show()
plt.imshow(high_cropped_img)

# %% [markdown]
# ### UNIQUE VALUES FROM AN ARRAY

# %%
np.unique(high_cropped_img)
# Out:
# array([ 67,  68,  69,  70,  71,  72,  73,  74,  78,  81,  82,  83,  84,
#         85,  86,  87,  88,  89,  90,  91,  92,  93,  94,  95,  96,  98,
#         99, 100, 101, 104], dtype=uint8)

# %% [markdown]
# ### AVERAGE PIXEL INTENSITY

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 83.89166666666667

# %%
low_image = Image.open("X-Rays/70_40.bmp")
plt.imshow(low_image)

# %% [markdown]
# ### Find K Value for Low Intensity

# %%
left = 59
top = 73
right = 70
bottom = 77
low_cropped_img = low_image.crop((left,top,right,bottom))
low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 74.52272727272727

# %%
high_image = Image.open("X-Rays/92_80.bmp")
plt.imshow(high_image)

# %% [markdown]
# ### Find K Value for High Intensity

# %%
left = 59
top = 68
right = 70
bottom = 72
high_cropped_img = high_image.crop((left,top,right,bottom))
high_cropped_img.show()
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 46.5

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.12284351827631

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.189

# %%
low_avg_pixel_intensity
# Out:
# 105.77777777777777

# %%
high_avg_pixel_intensity
# Out:
# 83.89166666666667

# %%
math.log(low_avg_pixel_intensity)
# Out:
# 4.661340457455146

# %%
(K * math.log(high_avg_pixel_intensity))
# Out:
# 4.973664876964863

# %%
math.log(high_avg_pixel_intensity)
# Out:
# 4.429526283947378

# %%
print(math.log(low_avg_pixel_intensity))
print(K * math.log(high_avg_pixel_intensity))
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 4.661340457455146
# 4.973664876964863
# -0.312324419509717

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
K
# Out:
# 0.04278257504577743
# 1.12284351827631

# %%
M_b = Numerator/Denominator

# %%
print(M_b)
# Out:
# -7.300271645068801

# %%
0.54-M_b
# Out:
# 7.8402716450688015

# %%
k_some = 0.192/0.163

# %% [markdown]
# k_some = 0.1823/0.165

# %%
k_some
# Out:
# 1.177914110429448

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (k_some * math.log(high_avg_pixel_intensity))
print(Numerator)
# Out:
# -0.5562610549245877

# %%
Denominator = mu_b_low - (k_some * mu_b_high)
print(Denominator)
# Out:
# 0.032374233128834334

# %%
M_b = Numerator/Denominator

# %%
0.54-M_b
# Out:
# 17.72221564387111

# %%
0.02568454545454546 * 1.003
# Out:
# 0.025761599090909092
