# %%
from PIL import Image, ImageOps
import numpy as np
from matplotlib import pyplot as plt
import cv2 as cv
import math

# %%
im1 = Image.open('X-Rays/70KV.jpg')
     
# applying equalize method 
low_image = ImageOps.equalize(im1, mask = None)

plt.imshow(low_image)

# %%
img = Image.open('X-Rays/92KV.jpg')
high_image = ImageOps.equalize(img, mask = None)
plt.imshow(high_image)

# %% [markdown]
# ### L1

# %%
left = 1000
top = 520 
right = 1250
bottom = 650
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 228.02904615384617

# %%
left = 1000
top = 520
right = 1250
bottom = 750
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 210.63179130434781

# %% [markdown]
# ## Crop the region containing soft tissues

# %%
left = 1500
top = 1195
right = 1526
bottom = 1205
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 85.58461538461539

# %%
left = 1449
top = 1196
right = 1480
bottom = 1212
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 84.18951612903226

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0037073939109968

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %% [markdown]
# <img src = "formula.jpg" />

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.05952650112164992

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05526222861171162

# %%
M_b1 = Numerator/Denominator

# %%
M_b1
# Out:
# 1.0771643239345323

# %% [markdown]
# ### L2

# %%
left = 1000
top = 785
right = 1250
bottom = 1000
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 216.3685023255814

# %%
left = 1000
top = 775
right = 1250
bottom = 960
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 203.4103135135135

# %%
left = 1500
top = 1197
right = 1519
bottom = 1205
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 86.26315789473684

# %%
left = 1449
top = 1192
right = 1481
bottom = 1215
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 85.91304347826087

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0009132339233

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.05690375150096649

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.0558182664492633

# %%
M_b2 = Numerator/Denominator

# %%
M_b2
# Out:
# 1.0194467711155069

# %% [markdown]
# ### L3

# %%
left = 1000
top = 985
right = 1250
bottom = 1200
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 192.2698046511628

# %%
left = 1000
top = 985
right = 1250
bottom = 1150
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 146.68002424242425

# %%
left = 1500
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 106.40384615384616

# %%
left = 1450
top = 1191
right = 1480
bottom = 1216
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 86.02933333333333

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0477145392716252

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.03263389176622944

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.04650480668494658

# %%
M_b3 = Numerator/Denominator

# %%
M_b3
# Out:
# 0.7017315863134831

# %% [markdown]
# ### L4

# %%
left = 950
top = 1185
right = 1250
bottom = 1300
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 197.59171014492753

# %%
left = 1000
top = 1185
right = 1200
bottom = 1350
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 150.2000303030303

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 106.84210526315789

# %%
left = 1449
top = 1190
right = 1480
bottom = 1221
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 87.35379812695109

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0450530389317656

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.04843050387036474

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.04703444525257863

# %%
M_b4 = Numerator/Denominator

# %%
M_b4
# Out:
# 1.0296816218473326

# %% [markdown]
# ### T12

# %%
left = 990
top = 340
right = 1230
bottom = 530
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 235.56993421052633

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %%
left = 1000
top = 350
right = 1220
bottom = 520
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 137.90898395721925

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 106.84210526315789

# %%
left = 1449
top = 1190
right = 1477
bottom = 1221
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 69.18202764976958

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.102581434278264

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.030036827350075512

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.035586294578625444

# %%
M_b5 = Numerator/Denominator

# %%
M_b5
# Out:
# 0.844056053200797

# %%
M_b1 ##L1
# Out:
# 1.0771643239345323

# %%
M_b2 ##L2
# Out:
# 1.0194467711155069

# %%
M_b3 ##L3
# Out:
# 0.7017315863134831

# %%
M_b4 ##L4
# Out:
# 1.0296816218473326

# %%
M_b5 ##T12
# Out:
# 0.844056053200797

# %%
M_b = (M_b1 + M_b2 + M_b3 + M_b4 + M_b5)/5
M_b
# Out:
# 0.9344160712823303

# %% [markdown]
# ### L1 - L2

# %%
im1 = Image.open('X-Rays/70KV.jpg')
     
# applying equalize method 
low_image = ImageOps.equalize(im1, mask = None)
  
plt.imshow(low_image)

# %%
left = 990
top = 540
right = 1280
bottom = 980
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 214.21815047021943

# %%
img = Image.open('X-Rays/92KV.jpg')
high_image = ImageOps.equalize(img, mask = None)
plt.imshow(high_image)

# %%
left = 1000
top = 540
right = 1230
bottom = 990
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 203.28855072463767

# %%
left = 1501
top = 1197
right = 1520
bottom = 1206
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 90.11695906432749

# %%
left = 1449
top = 1190
right = 1478
bottom = 1221
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 89.52502780867631

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0014662628940927

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.044575849118969835

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05570821368407555

# %%
Mb_l1l2 = Numerator/Denominator

# %%
Mb_l1l2
# Out:
# 0.8001665494385085

# %% [markdown]
# ### L1 - L3

# %%
im1 = Image.open('X-Rays/70KV.jpg')
     
# applying equalize method 
low_image = ImageOps.equalize(im1, mask = None)
  
plt.imshow(low_image)

# %%
left = 970
top = 550
right = 1290
bottom = 1175
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 202.01756

# %%
img = Image.open('X-Rays/92KV.jpg')
high_image = ImageOps.equalize(img, mask = None)
plt.imshow(high_image)

# %%
left = 980
top = 560
right = 1270
bottom = 1175
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 185.39840762545558

# %%
left = 1501
top = 1197
right = 1520
bottom = 1206
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 90.11695906432749

# %%
left = 1449
top = 1190
right = 1480
bottom = 1224
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 87.36148007590133

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.006947100536789

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.049566278451279366

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05461752699317901

# %%
Mb_l1l3 = Numerator/Denominator

# %%
Mb_l1l3
# Out:
# 0.9075159784782918

# %% [markdown]
# ### L1 - L4

# %%
im1 = Image.open('X-Rays/70KV.jpg')
     
# applying equalize method 
low_image = ImageOps.equalize(im1, mask = None)
  
plt.imshow(low_image)

# %%
left = 960
top = 550
right = 1290
bottom = 1320
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 199.82425423061787

# %%
img = Image.open('X-Rays/92KV.jpg')
high_image = ImageOps.equalize(img, mask = None)
plt.imshow(high_image)

# %%
left = 970
top = 560
right = 1270
bottom = 1330
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 182.21678354978354

# %%
left = 1501
top = 1197
right = 1520
bottom = 1205
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 86.69736842105263

# %%
left = 1450
top = 1191
right = 1482
bottom = 1225
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 83.49540441176471

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0085047931583078

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.047972030073788474

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.054307546161496745

# %%
Mb_l1l4 = Numerator/Denominator

# %%
Mb_l1l4
# Out:
# 0.8833400413845238

# %% [markdown]
# ### L2 - L3

# %%
im1 = Image.open('X-Rays/70KV.jpg')
     
# applying equalize method 
low_image = ImageOps.equalize(im1, mask = None)
  
plt.imshow(low_image)

# %%
left = 960
top = 770
right = 1280
bottom = 1180
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 197.3398780487805

# %%
img = Image.open('X-Rays/92KV.jpg')
high_image = ImageOps.equalize(img, mask = None)
plt.imshow(high_image)

# %%
left = 980
top = 775
right = 1260
bottom = 1190
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 180.8701290877797

# %%
left = 1501
top = 1197
right = 1520
bottom = 1205
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 86.69736842105263

# %%
left = 1450
top = 1191
right = 1482
bottom = 1226
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 83.97410714285714

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0072034683106854

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.04970621843131173

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.054566509806173585

# %%
Mb_l2l3 = Numerator/Denominator

# %%
Mb_l2l3
# Out:
# 0.9109290406858317

# %% [markdown]
# ### L2 - L4

# %%
im1 = Image.open('X-Rays/70KV.jpg')
     
# applying equalize method 
low_image = ImageOps.equalize(im1, mask = None)
  
plt.imshow(low_image)

# %%
left = 940
top = 760
right = 1290
bottom = 1340
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 192.3690197044335

# %%
img = Image.open('X-Rays/92KV.jpg')
high_image = ImageOps.equalize(img, mask = None)
plt.imshow(high_image)

# %%
left = 960
top = 770
right = 1270
bottom = 1340
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 175.60964346349746

# %%
left = 1501
top = 1197
right = 1520
bottom = 1205
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 86.69736842105263

# %%
left = 1450
top = 1191
right = 1481
bottom = 1224
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 83.91397849462365

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0073663324375506

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.053080760328271914

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.054534099844927436

# %%
Mb_l2l4 = Numerator/Denominator

# %%
Mb_l2l4
# Out:
# 0.973349894455245

# %% [markdown]
# ### L3 - L4

# %%
im1 = Image.open('X-Rays/70KV.jpg')
     
# applying equalize method 
low_image = ImageOps.equalize(im1, mask = None)
  
plt.imshow(low_image)

# %%
left = 940
top = 970
right = 1300
bottom = 1340
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 187.38755255255256

# %%
img = Image.open('X-Rays/92KV.jpg')
high_image = ImageOps.equalize(img, mask = None)
plt.imshow(high_image)

# %%
left = 960
top = 970
right = 1270
bottom = 1330
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 167.65363799283153

# %%
left = 1501
top = 1197
right = 1520
bottom = 1205
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 86.69736842105263

# %%
left = 1450
top = 1191
right = 1483
bottom = 1224
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 82.32782369146005

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0117247368042235

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.05122584172143796

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05366677737595951

# %%
Mb_l3l4 = Numerator/Denominator

# %%
Mb_l3l4
# Out:
# 0.9545168207619079

# %%
Mb_l1l2
# Out:
# 0.8001665494385085

# %%
Mb_l1l3
# Out:
# 0.9075159784782918

# %%
Mb_l1l4
# Out:
# 0.8833400413845238

# %%
Mb_l2l3
# Out:
# 0.9109290406858317

# %%
Mb_l2l4
# Out:
# 0.973349894455245

# %%
Mb_l3l4
# Out:
# 0.9545168207619079
