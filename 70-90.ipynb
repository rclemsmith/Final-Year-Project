# %% [markdown]
# ## Import the necessary libraries

# %%
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import math
import cv2 as cv

# %% [markdown]
# ## Read the image and normalize it.

# %%
img = cv.imread('X-Rays/70KV.jpg')
norm_img = np.zeros((800,800))
final_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
low_image = Image.fromarray(final_image)
plt.imshow(low_image)

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %% [markdown]
# ### L1

# %% [markdown]
# ## Crop the region containing the bone and the soft tissue.

# %%
left = 1000
top = 520 
right = 1250
bottom = 650
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 154.08135384615386

# %%
left = 1000
top = 520
right = 1250
bottom = 750
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 127.54321739130435

# %% [markdown]
# ## Crop the region containing the soft tissue.

# %%
left = 1500
top = 1197
right = 1526
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 74.79881656804734

# %%
left = 1449
top = 1196
right = 1480
bottom = 1212
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 66.39112903225806

# %% [markdown]
# ## Find K

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0284201672520286

# %% [markdown]
# ## Mass Attenuation Coefficients of Bone

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %% [markdown]
# ## Compute BMD by substituting the obtained values in the below formula

# %% [markdown]
# <img src="formula.jpg"/>

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.051231557954317

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05034438671684632

# %%
M_b1 = Numerator/Denominator

# %%
M_b1
# Out:
# 1.0176220487590886

# %% [markdown]
# ### L2

# %% [markdown]
# ## Crop the region containing the bone and the soft tissue

# %%
left = 1000
top = 785
right = 1250
bottom = 1000
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 146.05719069767443

# %%
left = 1000
top = 785
right = 1250
bottom = 970
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 127.0368

# %% [markdown]
# ## Crop the region containing the soft tissue.

# %%
left = 1500
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 73.4

# %%
left = 1449
top = 1192
right = 1480
bottom = 1209
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 68.32447817836812

# %% [markdown]
# ## Find K.

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.016962900928408

# %% [markdown]
# ## Mass Attenuation Coefficients of Bone

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %% [markdown]
# ## Compute the BMD by substituting the obtained values in the below formula.

# %% [markdown]
# <img src="formula.jpg"/>

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.05734507370131148

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.052624382715246804

# %%
M_b2 = Numerator/Denominator

# %%
M_b2
# Out:
# 1.0897053940111483

# %% [markdown]
# ### L3

# %%
left = 1000
top = 985
right = 1250
bottom = 1200
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 129.60816744186047

# %%
left = 1000
top = 985
right = 1250
bottom = 1150
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 94.28547878787879

# %%
left = 1500
top = 1197
right = 1520
bottom = 1216
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 87.69736842105263

# %%
left = 1449
top = 1191
right = 1480
bottom = 1215
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 67.92204301075269

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.060575966366431

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.04279045121278635

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.04394538269308024

# %%
M_b3 = Numerator/Denominator

# %%
M_b3
# Out:
# 0.9737189345155994

# %% [markdown]
# ### L4

# %%
left = 950
top = 1185
right = 1250
bottom = 1300
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 133.4322028985507

# %%
left = 1000
top = 1185
right = 1200
bottom = 1350
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 96.14096969696969

# %%
left = 1501
top = 1197
right = 1520
bottom = 1216
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 87.97506925207756

# %%
left = 1449
top = 1190
right = 1480
bottom = 1221
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 67.5525494276795

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0626996371564223

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.04150297844409678

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.043522772205871946

# %%
M_b4 = Numerator/Denominator

# %%
M_b4
# Out:
# 0.9535922539074232

# %% [markdown]
# ### T12

# %%
left = 990
top = 340
right = 1230
bottom = 530
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 160.66695175438596

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %%
left = 1000
top = 350
right = 1220
bottom = 520
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 137.90898395721925

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 73.64777327935222

# %%
left = 1449
top = 1190
right = 1480
bottom = 1221
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 67.5525494276795

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0205055863092254

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.05171697169724876

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05191938832446413

# %%
M_b5 = Numerator/Denominator

# %%
M_b5
# Out:
# 0.9961013287377272

# %%
M_b1 ##L1
# Out:
# 1.0176220487590886

# %%
M_b2 ##L2
# Out:
# 1.0897053940111483

# %%
M_b3 ##L3
# Out:
# 0.9737189345155994

# %%
M_b4 ##L4
# Out:
# 0.9535922539074232

# %%
M_b5 ##T12
# Out:
# 0.9961013287377272

# %%
BMD = (M_b1 + M_b2 + M_b3 + M_b4 + M_b5)/5
BMD
# Out:
# 1.0061479919861973

# %% [markdown]
# ### L1 - L2

# %%
img = cv.imread('X-Rays/70KV.jpg')
norm_img = np.zeros((800,800))
final_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
low_image = Image.fromarray(final_image)
plt.imshow(low_image)

# %%
left = 990
top = 540
right = 1280
bottom = 980
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 144.69740595611285

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %%
left = 1000
top = 540
right = 1230
bottom = 990
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 124.13340096618357

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 73.64777327935222

# %%
left = 1449
top = 1190
right = 1480
bottom = 1221
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 67.5525494276795

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0205055863092254

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.05442315683117638

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05191938832446413

# %%
Mb_l1l2 = Numerator/Denominator

# %%
Mb_l1l2
# Out:
# 1.048224152624165

# %% [markdown]
# ### L1 - L3

# %%
img = cv.imread('X-Rays/70KV.jpg')
norm_img = np.zeros((800,800))
final_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
low_image = Image.fromarray(final_image)
plt.imshow(low_image)

# %%
left = 970
top = 550
right = 1290
bottom = 1175
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 136.47764

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %%
left = 980
top = 560
right = 1270
bottom = 1175
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 114.83403980936362

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 73.64777327935222

# %%
left = 1449
top = 1190
right = 1483
bottom = 1224
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 66.2136678200692

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0253779810652808

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.052292690251440455

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05094978176800913

# %%
Mb_l1l3 = Numerator/Denominator

# %%
Mb_l1l3
# Out:
# 1.026357492354845

# %% [markdown]
# ### L1 - L4

# %%
img = cv.imread('X-Rays/70KV.jpg')
norm_img = np.zeros((800,800))
final_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
low_image = Image.fromarray(final_image)
plt.imshow(low_image)

# %%
left = 960
top = 550
right = 1290
bottom = 1320
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 135.01674931129477

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %%
left = 970
top = 560
right = 1270
bottom = 1330
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 113.27657575757576

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 73.64777327935222

# %%
left = 1450
top = 1191
right = 1482
bottom = 1225
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 65.86397058823529

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0266746036471952

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.04940003373134516

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.050691753874208156

# %%
Mb_l1l4 = Numerator/Denominator

# %%
Mb_l1l4
# Out:
# 0.9745181406414067

# %% [markdown]
# ### L2 - L3

# %%
img = cv.imread('X-Rays/70KV.jpg')
norm_img = np.zeros((800,800))
final_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
low_image = Image.fromarray(final_image)
plt.imshow(low_image)

# %%
left = 960
top = 770
right = 1280
bottom = 1180
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 133.2335899390244

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %%
left = 980
top = 775
right = 1260
bottom = 1190
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 112.14730636833046

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 73.64777327935222

# %%
left = 1450
top = 1191
right = 1482
bottom = 1226
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 66.07410714285714

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0258942344998843

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.050074709573790344

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05084704733452303

# %%
Mb_l2l3 = Numerator/Denominator

# %%
Mb_l2l3
# Out:
# 0.9848105681407325

# %% [markdown]
# ### L2 - L4

# %%
img = cv.imread('X-Rays/70KV.jpg')
norm_img = np.zeros((800,800))
final_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
low_image = Image.fromarray(final_image)
plt.imshow(low_image)

# %%
left = 940
top = 760
right = 1290
bottom = 1340
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 129.95188669950738

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %%
left = 960
top = 770
right = 1270
bottom = 1340
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 109.7003961516695

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 73.64777327935222

# %%
left = 1450
top = 1191
right = 1481
bottom = 1224
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 66.12903225806451

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.025690867177271

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.0487219533347254

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05088751743172304

# %%
Mb_l2l4 = Numerator/Denominator

# %%
Mb_l2l4
# Out:
# 0.9574441001193814

# %% [markdown]
# ### L3 - L4

# %%
img = cv.imread('X-Rays/70KV.jpg')
norm_img = np.zeros((800,800))
final_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
low_image = Image.fromarray(final_image)
plt.imshow(low_image)

# %%
left = 940
top = 970
right = 1300
bottom = 1340
low_cropped_img = low_image.crop((left,top,right,bottom))
plt.imshow(low_cropped_img)

# %%
low_avg_pixel_intensity = np.mean(low_cropped_img)
print(low_avg_pixel_intensity)
# Out:
# 126.64406156156156

# %%
img = cv.imread('X-Rays/92KV.jpg')
norm_img = np.zeros((800,800))
final_high_image = cv.normalize(img,  norm_img, 0, 255, cv.NORM_MINMAX)
high_image = Image.fromarray(final_high_image)
plt.imshow(high_image)

# %%
left = 960
top = 970
right = 1270
bottom = 1330
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
high_avg_pixel_intensity = np.mean(high_cropped_img)
print(high_avg_pixel_intensity)
# Out:
# 105.55595878136201

# %%
left = 1501
top = 1197
right = 1520
bottom = 1210
low_cropped_img = low_image.crop((left,top,right,bottom))
# low_cropped_img.show()
plt.imshow(low_cropped_img)

# %%
k_low_avg_pixel_intensity = np.mean(low_cropped_img)
print(k_low_avg_pixel_intensity)
# Out:
# 73.64777327935222

# %%
left = 1450
top = 1191
right = 1483
bottom = 1224
high_cropped_img = high_image.crop((left,top,right,bottom))
plt.imshow(high_cropped_img)

# %%
k_high_avg_pixel_intensity = np.mean(high_cropped_img)
print(k_high_avg_pixel_intensity)
# Out:
# 65.24334251606979

# %%
K = math.log(k_low_avg_pixel_intensity)/math.log(k_high_avg_pixel_intensity)
K
# Out:
# 1.0290010295852312

# %%
mu_b_low = 0.255

# %%
mu_b_high = 0.199

# %%
Numerator = (math.log(low_avg_pixel_intensity)) - (K * math.log(high_avg_pixel_intensity)) 
print(Numerator)
# Out:
# 0.04701646680785743

# %%
Denominator = mu_b_low - (K * mu_b_high)
print(Denominator)
# Out:
# 0.05022879511253897

# %%
Mb_l3l4 = Numerator/Denominator

# %%
Mb_l3l4
# Out:
# 0.9360460807892318

# %%
Mb_l1l2
# Out:
# 1.048224152624165

# %%
Mb_l1l3
# Out:
# 1.026357492354845

# %%
Mb_l1l4
# Out:
# 0.9745181406414067

# %%
Mb_l2l3
# Out:
# 0.9848105681407325

# %%
Mb_l2l4
# Out:
# 0.9574441001193814

# %%
Mb_l3l4
# Out:
# 0.9360460807892318
